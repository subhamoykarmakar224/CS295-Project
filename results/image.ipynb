# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns
import math
# Declaring the points for first line plot
X1 = [100*i for i in range(1, 11)] 
Y1 = [12253, 22279, 32352, 43277, 53344, 64312, 74406, 85337, 95406, 106389] 
Y1 = [math.log(y) for y in Y1]
Y2 = [106231, 211625, 316016, 421390, 525767, 631122, 736508, 840869, 946235, 1051596]
# Y2 = [106231, 211625, 316016]
Y2 = [math.log(y) for y in Y2]
Y3 = [12092, 22100, 33117, 33117, 43132, 43133, 54150, 64153, 64154, 75185]
Y3 = [math.log(y) for y in Y3]
# plotting the first plot

plt.plot(X1, Y2, label = "batch size 10 txns")
plt.plot(X1, Y1, label="batch size 100 txns")
plt.plot(X1, Y3, label = "batch size 1000 txns")
# Declaring the points for second line plot
# X2 = [1,2,3,4,5] 
# Y2 = [1,4,9,16,25]

# # plotting the second plot 
# plt.plot(X2, Y2, label = "plot 2") 
  
# Labeling the X-axis 
plt.xlabel('Number of transactions') 

# Labeling the Y-axis 
plt.ylabel('Log(Time (ms))') 
plt.xticks(X1, np.arange(100, 1010, 100))
# Give a title to the graph
plt.title('Amount of time it takes for transactions to be committed') 
  
# Show a legend on the plot 
plt.legend() 

# 

plt.savefig('commit', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
purpDB = [(424), (1188), (1908), (2401)]
purpTable = [(407), (1134), (1781), (2339)]
strDel = "DELETE"
strDelVac = "DELETE + VACUUM"
strDelFull = "DELETE + VACUUM FULL"
tombstone = "Tombstoning with indexing"
delarr = [strDel, strDel, strDel, strDel, strDelVac, strDelVac, strDelVac, strDelVac, strDelFull, strDelFull, strDelFull, strDelFull, tombstone, tombstone, tombstone, tombstone]
print(len(delarr))
trans = ["10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K"]
print(len(trans))
time = delete + delUnVac + delVac + delTomb
print(len(time))
print(time)
data = {"Delete Type": delarr,
        "Transactions": trans,
        "Time (seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time (seconds)", hue="Delete Type", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload")
plt.savefig('controllerDelete', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# 5.991464547107982
# 16
# 16
# 16
# [400, 1044, 1617, 2042, 376, 1003, 1519, 1966, 456, 1379, 2271, 3175, 438, 1321, 2261, 3168]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
purpDB = [(424), (1188), (1908), (2401)]
purpTable = [(407), (1134), (1781), (2339)]
purposeInTable = "Purpose in table"
purposeSepDB = "Seperate DB Purpose"
purposeSepTable = "Seperate table Purpose"
purarr = [purposeInTable, purposeInTable, purposeInTable, purposeInTable,  purposeSepDB, purposeSepDB, purposeSepDB, purposeSepDB, purposeSepTable, purposeSepTable, purposeSepTable, purposeSepTable]
print(len(purarr))
trans = ["10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K"]
print(len(trans))
time = delete + purpDB + purpTable
print(len(time))
print(time)
data = {"Purpose Type": purarr,
        "Transactions": trans,
        "Time (seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time (seconds)", hue="Purpose Type", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload")
plt.savefig('PurposeController', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# 5.991464547107982
# 12
# 12
# 12
# [400, 1044, 1617, 2042, 424, 1188, 1908, 2401, 407, 1134, 1781, 2339]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
purpDB = [(424), (1188), (1908), (2401)]
purpTable = [(407), (1134), (1781), (2339)]
enc = [(585),(1607),(2506),(3283)]
purposeInTable = "Purpose in table"
purposeSepDB = "Seperate DB Purpose"
purposeSepTable = "Seperate table Purpose"
encrypt = ""
purarr = [encrypt, encrypt, encrypt, encrypt]
print(len(purarr))
trans = ["10K", "30K", "50K", "70K"]
print(len(trans))
time = enc
print(len(time))
print(time)
data = {"Encryption": purarr,
        "Transactions": trans,
        "Time (seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time (seconds)", hue="Encryption", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload with Encryption")
plt.savefig('Encryption', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 5.991464547107982
# 4
# 4
# 4
# [585, 1607, 2506, 3283]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
purpDB = [(424), (1188), (1908), (2401)]
purpTable = [(407), (1134), (1781), (2339)]
enc = [np.log10(585),np.log10(1607),np.log10(2506),np.log10(3283)]
purposeInTable = "Purpose in table"
purposeSepDB = "Seperate DB Purpose"
purposeSepTable = "Seperate table Purpose"
encrypt = ""
purarr = [encrypt, encrypt, encrypt, encrypt]
print(len(purarr))
trans = ["10K", "30K", "50K", "70K"]
print(len(trans))
time = enc
print(len(time))
print(time)
data = {"Encryption": purarr,
        "Transactions": trans,
        "Time Log(seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time Log(seconds)", hue="Encryption", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload with Encryption")
plt.savefig('EncryptionLog10', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 5.991464547107982
# 4
# 4
# 4
# [2.7671558660821804, 3.2060158767633444, 3.398981066658131, 3.5162708827293403]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
delete = [(585), (1607), (2506), (3283)]
purpDB = [(597), (1700), (2637), (3401)]
purpTable = [(693), (1839), (2887), (3608)]
purposeInTable = "LUKS Encryption"
purposeSepDB = "ZFS AES-256-GCM"
purposeSepTable = "ZFS AES-128-GCM"
purarr = [purposeInTable, purposeInTable, purposeInTable, purposeInTable,  purposeSepDB, purposeSepDB, purposeSepDB, purposeSepDB, purposeSepTable, purposeSepTable, purposeSepTable, purposeSepTable]
print(len(purarr))
trans = ["10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K"]
print(len(trans))
time = delete + purpDB + purpTable
print(len(time))
print(time)
data = {"Encryption Type": purarr,
        "Transactions": trans,
        "Time (seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time (seconds)", hue="Encryption Type", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload")
plt.savefig('EncryptionController', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# 5.991464547107982
# 12
# 12
# 12
# [585, 1607, 2506, 3283, 597, 1700, 2637, 3401, 693, 1839, 2887, 3608]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
print(np.log(400))
delete = [(400), (1044), (1617), (2042)]
delUnVac = [(376), (1003), (1519), (1966)]
delVac = [(456), (1379), (2271), (3175)]
delTomb = [(438), (1321), (2261), (3168)]
delete = [np.log10(585), np.log10(1607), np.log10(2506), np.log10(3283)]
purpDB = [np.log10(597), np.log10(1700), np.log10(2637), np.log10(3401)]
purpTable = [np.log10(693), np.log10(1839), np.log10(2887), np.log10(3608)]
purposeInTable = "LUKS Encryption"
purposeSepDB = "ZFS AES-256-GCM"
purposeSepTable = "ZFS AES-128-GCM"
purarr = [purposeInTable, purposeInTable, purposeInTable, purposeInTable,  purposeSepDB, purposeSepDB, purposeSepDB, purposeSepDB, purposeSepTable, purposeSepTable, purposeSepTable, purposeSepTable]
print(len(purarr))
trans = ["10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K", "10K", "30K", "50K", "70K"]
print(len(trans))
time = delete + purpDB + purpTable
print(len(time))
print(time)
data = {"Encryption Type": purarr,
        "Transactions": trans,
        "Time Log10(seconds)": time}


# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data=data)
df.head()
plt.figure(figsize=(8, 12))
plots = sns.barplot(x="Transactions", y="Time Log10(seconds)", hue="Encryption Type", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
# for bar in plots.patches:
   
#         # Using Matplotlib's annotate function and
#         # passing the coordinates where the annotation shall be done
#         if i == 2:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         else:
#                 plots.annotate(format(bar.get_height(), '.2f'),
#                                 (bar.get_x() + bar.get_width() / 2,
#                                 bar.get_height()), ha='center', va='center',
#                                 size=10, xytext=(0, 5),
#                                 textcoords='offset points')
#         i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload")
plt.savefig('EncryptionLogController', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()
# Out:
# 5.991464547107982
# 12
# 12
# 12
# [2.7671558660821804, 3.2060158767633444, 3.398981066658131, 3.5162708827293403, 2.775974331129369, 3.230448921378274, 3.4211101297934343, 3.531606631932722, 2.8407332346118066, 3.2645817292380777, 3.4604467838807205, 3.557266528869904]

# %%
#data = {'Controller':586, 'Customer':514, 'Processor':663}
data = {"Logs": ["Delete", "D + Unlock Vacc", "D + Lock Vacc", "Tombstone"],
        "Scale": [1.064516129, 1, 4.7399605, 1.566820276]}
# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data, columns=['Logs', 'Scale'])
plt.figure(figsize=(10, 6))
plots = sns.barplot(x="Logs", y="Scale", data=df)
# plt.bar(courses, values, color ='blue')
i = 0
for bar in plots.patches:
   
        # Using Matplotlib's annotate function and
        # passing the coordinates where the annotation shall be done
        if i == 2:
                plots.annotate(format(bar.get_height(), '.2f'),
                                (bar.get_x() + bar.get_width() / 2,
                                bar.get_height()), ha='center', va='center',
                                size=15, xytext=(0, 5),
                                textcoords='offset points')
        else:
                plots.annotate(format(bar.get_height(), '.2f'),
                                (bar.get_x() + bar.get_width() / 2,
                                bar.get_height()), ha='center', va='center',
                                size=15, xytext=(0, 5),
                                textcoords='offset points')
        i+=1

# plt.xlabel("GDPRBench Controller workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Controller Workload Ratio")
plt.savefig('controller Ratio', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()

# %%
#data = {'Controller':629, 'Customer':523, 'Processor':678}
data = {"Logs": ["LogChain('C1')", "csvlog(C1)", "LogChain('C2')", "csvlog(C2)", "LogChain('P')", "csvlog(P)"],
        "Time (seconds)": [514, 523, 586, 629, 663, 678]}
# data = {'LogChain':586, 'csvlog':629}
# courses = list(data.keys())
# values = list(data.values())
df = pd.DataFrame(data, columns=['Logs', 'Time (seconds)'])
# data = {'LogChain':514, 'csvlog':523}
# courses = list(data.keys())
# values = list(data.values())
plt.figure(figsize=(10, 6))
plots = sns.barplot(x="Logs", y="Time (seconds)", data=df)
# plt.bar(courses, values, color ='blue')
for bar in plots.patches:
   
    # Using Matplotlib's annotate function and
    # passing the coordinates where the annotation shall be done
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=12, xytext=(0, 5),
                   textcoords='offset points')
# plt.xlabel("GDPRBench Customer workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench workloads")
plt.savefig('Customer', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()

# %%
# data = {'LogChain':663, 'csvlog':678}
data = {"Logs": ["LogChain", "csvlog"],
        "Time (seconds)": [663, 678]}
df = pd.DataFrame(data, columns=['Logs', 'Time (seconds)'])
# courses = list(data.keys())
# values = list(data.values())
plt.figure(figsize=(3, 6))
plots = sns.barplot(x="Logs", y="Time (seconds)", data=df)
# plt.bar(courses, values, color ='blue')
for bar in plots.patches:
   
    # Using Matplotlib's annotate function and
    # passing the coordinates where the annotation shall be done
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 5),
                   textcoords='offset points')
# # plt.xlabel("GDPRBench Customer workload")
# plt.ylabel("Time (Seconds)")
plt.title("GDPRBench Processor workload")
plt.savefig('processor', dpi = 100, transparent=True, bbox_inches = "tight")
plt.show()

# %%
#127
